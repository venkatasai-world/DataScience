# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/QueryResults.csv')

# %%
df.head()
# Out:
#                      m     TagName  Unnamed: 2
# 0  2008-07-01 00:00:00          c#           3
# 1  2008-08-01 00:00:00    assembly           8
# 2  2008-08-01 00:00:00  javascript         162
# 3  2008-08-01 00:00:00           c          85
# 4  2008-08-01 00:00:00      python         124

# %%
df.shape
# Out:
# (1991, 3)

# %%
df.shape[1]
# Out:
# 3

# %%
df1=pd.read_csv('/content/QueryResults.csv',names=['Date','TAG','POST'],header=0)

# %%
df1.head()
# Out:
#                   Date         TAG  POST
# 0  2008-07-01 00:00:00          c#     3
# 1  2008-08-01 00:00:00    assembly     8
# 2  2008-08-01 00:00:00  javascript   162
# 3  2008-08-01 00:00:00           c    85
# 4  2008-08-01 00:00:00      python   124

# %%
df.count()
# Out:
# m             1991
# TagName       1991
# Unnamed: 2    1991
# dtype: int64

# %%
df1.groupby('TAG').count()
# Out:
#             Date  POST
# TAG
# assembly     144   144
# c            144   144
# c#           145   145
# c++          144   144
# delphi       144   144
# go           129   129
# java         144   144
# javascript   144   144
# perl         144   144
# php          144   144
# python       144   144
# r            142   142
# ruby         144   144
# swift        135   135

# %%
df1.Date[1]
# Out:
# '2008-08-01 00:00:00'

# %%
type(df1.Date[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df1.Date=pd.to_datetime(df1.Date)

# %%
df.head()
# Out:
#                      m     TagName  Unnamed: 2
# 0  2008-07-01 00:00:00          c#           3
# 1  2008-08-01 00:00:00    assembly           8
# 2  2008-08-01 00:00:00  javascript         162
# 3  2008-08-01 00:00:00           c          85
# 4  2008-08-01 00:00:00      python         124

# %%
test_df=pd.DataFrame({'Age':['Young','Young','Young','young','Old','Old',"Old","Old"],'Actor':['Jack', 'Arnold', 'Keanu', 'Sylvester', 'Jack', 'Arnold', 'Keanu', 'Sylvester'],'Power': [100, 80, 25, 50, 99, 75, 5, 30]})

# %%
test_df
# Out:
#      Age      Actor  Power
# 0  Young       Jack    100
# 1  Young     Arnold     80
# 2  Young      Keanu     25
# 3  young  Sylvester     50
# 4    Old       Jack     99
# 5    Old     Arnold     75
# 6    Old      Keanu      5
# 7    Old  Sylvester     30

# %%
pivoted_df = test_df.pivot(index='Age', columns='Actor', values='Power')
pivoted_df
# Out:
# Actor  Arnold   Jack  Keanu  Sylvester
# Age
# Old      75.0   99.0    5.0       30.0
# Young    80.0  100.0   25.0        NaN
# young     NaN    NaN    NaN       50.0

# %%
reshaped_df=df1.pivot(index='Date',columns='TAG',values='POST')
reshaped_df
# Out:
# TAG         assembly       c       c#     c++  delphi     go     java  \
# Date
# 2008-07-01       NaN     NaN      3.0     NaN     NaN    NaN      NaN
# 2008-08-01       8.0    85.0    511.0   164.0    14.0    NaN    222.0
# 2008-09-01      28.0   321.0   1649.0   755.0   105.0    NaN   1137.0
# 2008-10-01      15.0   303.0   1989.0   811.0   112.0    NaN   1153.0
# 2008-11-01      17.0   259.0   1730.0   735.0   141.0    NaN    958.0
# ...              ...     ...      ...     ...     ...    ...      ...
# 2020-03-01     317.0  2670.0   8954.0  5107.0   181.0  719.0  13253.0
# 2020-04-01     406.0  3472.0  10042.0  6820.0   250.0  887.0  15377.0
# 2020-05-01     386.0  3602.0   9923.0  7063.0   221.0  826.0  14711.0
# 2020-06-01     363.0  2757.0   9064.0  6161.0   214.0  765.0  13015.0
# 2020-07-01     298.0  2294.0   9145.0  5756.0   212.0  743.0  12723.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# Date
# ...

# %%
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.figure(figsize=(16,10))

# %%
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
# Out:
# (0.0, 35000.0)

# %%
plt.plot(reshaped_df.index, reshaped_df.java, label='Java', color='r')
plt.plot(reshaped_df.index, reshaped_df.python, label='Python', color='g')

# %%
for column in reshaped_df.columns:
    plt.plot(reshaped_df.index, reshaped_df[column])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

for column in reshaped_df.columns:
    plt.plot(reshaped_df.index, reshaped_df[column],
             linewidth=3, label=reshaped_df[column].name)

# %%
roll_df = reshaped_df.rolling(window=6).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

# plot the roll_df instead
for column in roll_df.columns:
    plt.plot(roll_df.index, roll_df[column],
             linewidth=3, label=roll_df[column].name)
